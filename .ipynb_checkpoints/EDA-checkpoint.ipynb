# %%
import pandas as pd

# %%
df = pd.read_csv('https://query.data.world/s/bzyscgfsf4xkehchlyrhztbumexhux')

# %%
df.describe(include = "all")
# Out:
#         Unnamed: 0         Age Eliminated       Hometown Name Occupation  \
# count   479.000000  478.000000        152            479  479        479
# unique         NaN         NaN         11            372  473        343
# top            NaN         NaN     Week 1  Dallas, Texas  Amy   Attorney
# freq           NaN         NaN         62             11    2         13
# mean     13.160752   26.345188        NaN            NaN  NaN        NaN
# std       7.876216    2.763965        NaN            NaN  NaN        NaN
# min       0.000000   21.000000        NaN            NaN  NaN        NaN
# 25%       6.000000   24.000000        NaN            NaN  NaN        NaN
# 50%      13.000000   26.000000        NaN            NaN  NaN        NaN
# 75%      20.000000   28.000000        NaN            NaN  NaN        NaN
# max      30.000000   36.000000        NaN            NaN  NaN        NaN
#
#        Outcome      Season
# count      211  479.000000
# unique      35         NaN
# ...

# %%
df[df['Outcome'] == "Winner"]
# Out:
#      Unnamed: 0   Age Eliminated                   Hometown  \
# 152           0  22.0        NaN         Malibu, California
# 177           0  25.0        NaN              Dallas, Texas
# 202           0  23.0        NaN            Geneva, Florida
# 227           0  25.0        NaN  Morgantown, West Virginia
# 257           0  28.0        NaN        Scottsdale, Arizona
# 282           0  26.0        NaN        Seattle, Washington
# 308           0  26.0        NaN          Kearney, Missouri
# 335           0  29.0        NaN    Louisville, Kentucky[a]
# 365           0  25.0        NaN          West Linn, Oregon
# 423           1  27.0        NaN      Prior Lake, Minnesota
#
#                            Name                         Occupation Outcome  \
# 152             Shayne Lamas[1]                            Actress  Winner
# 177          Melissa Rycroft[1]               Sales Representative  Winner
# 202        Vienna Girardi[1][2]           Marketing Representative  Winner
# ...
